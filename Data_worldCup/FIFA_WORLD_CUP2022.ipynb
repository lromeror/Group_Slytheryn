# %%
import numpy as np
import pandas as pd

# %%
players_fifa_wc2022= pd.read_excel('../Data_worldCup/Players.xlsx',sheet_name='player_stats')
players_fifa_wc2022.replace('Angel Di Mar�a','Angel Di María',inplace=True)
players_fifa_wc2022.replace('A�ssa La�douni','Aissa Laidouni',inplace=True)
players_fifa_wc2022
# Out:
#                    player position        team     age  age2             club
# 0              Aaron Mooy       MF   Australia  32-094    32           Celtic  \
# 1            Aaron Ramsey       MF       Wales  31-357    31             Nice
# 2       Abdelhamid Sabiri       MF     Morocco  26-020    26        Sampdoria
# 3       Abdelkarim Hassan       DF       Qatar  29-112    29       Al Sadd SC
# 4    Abderrazak Hamdallah       FW     Morocco  32-001    32       Al-Ittihad
# ..                    ...      ...         ...     ...   ...              ...
# 675        Angel Di María       MF   Argentina  34-307    34         Juventus
# 676       Ángelo Preciado       DF     Ecuador  24-303    24             Genk
# 677          Éder Militão       DF      Brazil  24-334    24      Real Madrid
# 678          Óscar Duarte       DF  Costa Rica  33-198    33         Al-Wehda
# 679        İlkay Gundogan       MF     Germany  32-055    32  Manchester City
#
#      birth_year  games  games_starts  minutes  ...  goals_assists_pens_per90
# 0          1990      4             4      360  ...                         0  \
# 1          1990      3             3      266  ...                         0
# 2          1996      5             2      181  ...                         5
# 3          1993      3             3      270  ...                         0
# 4          1990      4             0       68  ...                         0
# ..          ...    ...           ...      ...  ...                       ...
# 675        1988      5             4      288  ...                        62
# 676        1998      3             3      264  ...                        34
# 677        1998      4             4      347  ...                         0
# 678        1989      3             3      270  ...                         0
# 679        1990      3             3      189  ...                         0
#
#        xg  npxg  xg_assist  npxg_xg_assist  xg_per90  xg_assist_per90
# 0     0.0   0.0        1.0             1.0       1.0              2.0  \
# 1     0.0   0.0        0.0             1.0       1.0              1.0
# 2     1.0   1.0        9.0             1.0       8.0             53.0
# 3     3.0   3.0        0.0             3.0       1.0              1.0
# 4     4.0   4.0        0.0             4.0      52.0              0.0
# ..    ...   ...        ...             ...       ...              ...
# 675   8.0   8.0        6.0            14.0      27.0              2.0
# 676   1.0   1.0        4.0             5.0       2.0             14.0
# 677   2.0   2.0        0.0             2.0       5.0              1.0
# 678   0.0   0.0        3.0             3.0       0.0              9.0
# 679  11.0   4.0        1.0             5.0      54.0              5.0
#
#      xg_xg_assist_per90  npxg_per90  npxg_xg_assist_per90
# 0                   3.0         1.0                   3.0
# 1                   2.0         1.0                   2.0
# 2                   6.0         8.0                   6.0
# 3                  11.0         1.0                  11.0
# 4                  52.0        52.0                  52.0
# ..                  ...         ...                   ...
# 675                46.0        27.0                  46.0
# 676                17.0         2.0                  17.0
# 677                 5.0         5.0                   5.0
# 678                 9.0         0.0                   9.0
# 679                 6.0        17.0                  22.0
#
# [680 rows x 32 columns]

# %%
matches_fifa_wc2022 = pd.read_excel('../Data_worldCup/Matches.xlsx',sheet_name='Fifa_WC_2022_Match_data')
matches_fifa_wc2022.columns=matches_fifa_wc2022.loc[0]
matches_fifa_wc2022.drop(0,axis=0,inplace=True)
matches_fifa_wc2022
# Out:
# 0  match_no day_of_week       date   hour                          venue
# 1         1         Sun  20-Nov-22  17:00                Al Bayt Stadium  \
# 2         2         Mon  21-Nov-22  14:00  Khalifa International Stadium
# 3         3         Mon  21-Nov-22  17:00             Al Thumama Stadium
# 4         4         Mon  21-Nov-22  20:00          Ahmed bin Ali Stadium
# 5         5         Tue  22-Nov-22  11:00          Lusail Iconic Stadium
# ..      ...         ...        ...    ...                            ...
# 60       60         Sat  10-Dec-22  20:00                Al Bayt Stadium
# 61       61         Tue  13-Dec-22  20:00          Lusail Iconic Stadium
# 62       62         Wed  14-Dec-22  20:00                Al Bayt Stadium
# 63       63         Sat  17-Dec-22  16:00  Khalifa International Stadium
# 64       64         Sun  18-Dec-22  16:00          Lusail Iconic Stadium
#
# 0                         referee                     group              1
# 1                  Daniele Orsato                   Group A          QATAR  \
# 2                   Raphael Claus                   Group B        ENGLAND
# 3                  Wilton Sampaio                   Group A        SENEGAL
# 4   Abdulrahman Ibrahim Al Jassim                   Group B  UNITED STATES
# 5                   Slavko Vincic                   Group C      ARGENTINA
# ..                            ...                       ...            ...
# 60                 Wilton Sampaio             Quarter-final        ENGLAND
# 61                 Daniele Orsato                Semi-Final      ARGENTINA
# 62                    Cesar Ramos                Semi-Final         FRANCE
# 63  Abdulrahman Ibrahim Al Jassim  Play-off for third place        CROATIA
# 64               Szymon Marciniak                     Final      ARGENTINA
#
# 0              2 attendance  ... 1_panelties_scored 2_panelties_scored
# 1        ECUADOR      67372  ...                  0                  1  \
# 2           IRAN      45334  ...                  0                  1
# 3    NETHERLANDS      41721  ...                  0                  0
# 4          WALES      43418  ...                  0                  1
# 5   SAUDI ARABIA      88012  ...                  1                  0
# ..           ...        ...  ...                ...                ...
# 60        FRANCE      68895  ...                  1                  0
# 61       CROATIA      88966  ...                  1                  0
# 62       MOROCCO      68294  ...                  0                  0
# 63       MOROCCO      44137  ...                  0                  0
# 64        FRANCE      88966  ...                  1                  2
#
# 0  1_goal_prevented 2_goal_prevented 1_own_goal 2_own_goal 1_forced_turnovers
# 1                 6                5          0          0                 52  \
# 2                 8               13          0          0                 63
# 3                 9               15          0          0                 63
# 4                 7                7          0          0                 81
# 5                 4               14          0          0                 65
# ..              ...              ...        ...        ...                ...
# 60                9               15          0          0                 49
# 61               12               10          0          0                 85
# 62               13               14          0          0                 72
# 63                7               14          0          0                 75
# 64               11               21          0          0                 87
#
# 0  2_forced_turnovers 1_defensive_pressure_applied
# 1                  72                          256  \
# 2                  72                          139
# 3                  73                          263
# 4                  72                          242
# 5                  80                          163
# ..                ...                          ...
# 60                 54                          193
# 61                 63                          321
# 62                 47                          328
# 63                 72                          288
# 64                104                          280
#
# 0  2_defensive_pressure_applied
# 1                           279
# 2                           416
# 3                           251
# 4                           292
# 5                           361
# ..                          ...
# 60                          308
# 61                          260
# 62                          218
# 63                          277
# 64                          409
#
# [64 rows x 59 columns]

# %%
hola = pd.read_html('https://www.sportingnews.com/us-es/futbol/news/listas-mundial-qatar-2022-selecciones-jugadores/av9gonsnjlpsqget04qlf8md')
hola[1]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 hola = pd.read_html('https://www.sportingnews.com/us-es/futbol/news/listas-mundial-qatar-2022-selecciones-jugadores/av9gonsnjlpsqget04qlf8md')
#       2 hola[1]
#
# File ~/Repositorios_GitHub/espol_env/lib/python3.11/site-packages/pandas/io/html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1208 check_dtype_backend(dtype_backend)
#    1210 io = stringify_path(io)
# -> 1212 return _parse(
#    1213     flavor=flavor,
#    1214     io=io,
#    1215     match=match,
#    1216     header=header,
#    1217     index_col=index_col,
#    1218     skiprows=skiprows,
#    1219     parse_dates=parse_dates,
#    1220     thousands=thousands,
#    1221     attrs=attrs,
#    1222     encoding=encoding,
#    1223     decimal=decimal,
#    1224     converters=converters,
#    1225     na_values=na_values,
#    1226     keep_default_na=keep_default_na,
#    1227     displayed_only=displayed_only,
#    1228     extract_links=extract_links,
#    1229     dtype_backend=dtype_backend,
#    1230 )
#
# File ~/Repositorios_GitHub/espol_env/lib/python3.11/site-packages/pandas/io/html.py:981, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     978 p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     980 try:
# --> 981     tables = p.parse_tables()
#     982 except ValueError as caught:
#     983     # if `io` is an io-like object, check if it's seekable
#     984     # and try to rewind it before trying the next parser
#     985     if hasattr(io, "seekable") and io.seekable():
#
# File ~/Repositorios_GitHub/espol_env/lib/python3.11/site-packages/pandas/io/html.py:257, in _HtmlFrameParser.parse_tables(self)
#     249 def parse_tables(self):
#     250     """
#     251     Parse and return all tables from the DOM.
#     252
#    (...)
#     255     list of parsed (header, body, footer) tuples from tables.
#     256     """
# --> 257     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     258     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~/Repositorios_GitHub/espol_env/lib/python3.11/site-packages/pandas/io/html.py:816, in _LxmlFrameParser._build_doc(self)
#     814             pass
#     815     else:
# --> 816         raise e
#     817 else:
#     818     if not hasattr(r, "text_content"):
#
# File ~/Repositorios_GitHub/espol_env/lib/python3.11/site-packages/pandas/io/html.py:797, in _LxmlFrameParser._build_doc(self)
#     795 try:
#     796     if is_url(self.io):
# --> 797         with urlopen(self.io) as f:
#     798             r = parse(f, parser=parser)
#     799     else:
#     800         # try to parse the input in the simplest way
#
# File ~/Repositorios_GitHub/espol_env/lib/python3.11/site-packages/pandas/io/common.py:270, in urlopen(*args, **kwargs)
#     264 """
#     265 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     266 the stdlib.
#     267 """
#     268 import urllib.request
# --> 270 return urllib.request.urlopen(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden
