# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2023

# %%
datasa_2023=["awards_2023_asesoria_y_patrocinio_juridico.csv","contracts_2023_asesoria_y_patrocinio_juridico.csv","extensions_2023_asesoria_y_patrocinio_juridico.csv","metadata_2023_asesoria_y_patrocinio_juridico.csv","planning_2023_asesoria_y_patrocinio_juridico.csv","releases_2023_asesoria_y_patrocinio_juridico.csv","suppliers_2023_asesoria_y_patrocinio_juridico.csv","tender_2023_asesoria_y_patrocinio_juridico.csv"]
datas_dir ="assets/data/releases_2023_asesoria_y_patrocinio_juridico/"
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### awards_2023_asesoria_y_patrocinio_juridico.csv

# %%
awards_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[0]),sep=",")
awards_2023_df.head(10)
# Out:
#                                       ocid
# 0    ocds-5wno2w-REAJ-CBBF-001-2023-166651  \
# 1         ocds-5wno2w-RE-APG-001-2023-2499
# 2    ocds-5wno2w-REAJ-CBCB-001-2023-498171
# 3     ocds-5wno2w-RE-APJ-BCBG-04-2023-2528
# 4  ocds-5wno2w-RE-APJ-EMOVEP-1-2023-315805
# 5    ocds-5wno2w-RREAPJ-CFNGYE-1-2023-2469
# 6   ocds-5wno2w-RE-APJ-EPA-002-2023-555086
# 7  ocds-5wno2w-RE-APJ-EPMMQ-01-2023-410205
# 8     ocds-5wno2w-GADPRA-001-AJ-2023-94956
# 9     ocds-5wno2w-RE-APJC-GADMA-01-23-2422
#
#                                           release_id
# 0  REAJ-CBBF-001-2023-166651-2023-08-22T19:29:19....  \
# 1  RE-APG-001-2023-2499-2023-08-22T19:27:03.571Z-...
# 2  REAJ-CBCB-001-2023-498171-2023-02-01T10:32:22....
# 3  RE-APJ-BCBG-04-2023-2528-2023-08-22T19:10:50.566Z
# 4  RE-APJ-EMOVEP-1-2023-315805-2023-08-22T19:28:3...
# 5  RREAPJ-CFNGYE-1-2023-2469-2023-08-22T19:45:25....
# 6  RE-APJ-EPA-002-2023-555086-2023-08-22T20:04:24...
# 7  RE-APJ-EPMMQ-01-2023-410205-2023-08-23T02:29:1...
# ...

# %%
#Columnas 
awards_2023_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status', 'date',
#        'amount', 'currency', 'correctedValue_amount',
#        'correctedValue_currency', 'enteredValue_amount',
#        'enteredValue_currency', 'contractPeriod_startDate',
#        'contractPeriod_endDate', 'contractPeriod_maxExtentDate',
#        'contractPeriod_durationInDays'],
#       dtype='object')

# %%
awards_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ocid                           29 non-null     object
#  1   release_id                     29 non-null     object
#  2   id                             29 non-null     object
#  3   title                          0 non-null      float64
#  4   description                    29 non-null     object
#  5   status                         0 non-null      float64
#  6   date                           29 non-null     object
#  7   amount                         29 non-null     float64
#  8   currency                       29 non-null     object
#  9   correctedValue_amount          0 non-null      float64
#  10  correctedValue_currency        0 non-null      float64
#  11  enteredValue_amount            0 non-null      float64
# ...

# %% [markdown]
# ### contracts_2023_asesoria_y_patrocinio_juridico.csv

# %%
contracts_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[1]),sep=",")
contracts_2023_df.head(10)
# Out:
#                                       ocid
# 0    ocds-5wno2w-REAJ-CBBF-001-2023-166651  \
# 1         ocds-5wno2w-RE-APG-001-2023-2499
# 2    ocds-5wno2w-REAJ-CBCB-001-2023-498171
# 3     ocds-5wno2w-RE-APJ-BCBG-04-2023-2528
# 4  ocds-5wno2w-RE-APJ-EMOVEP-1-2023-315805
# 5    ocds-5wno2w-RREAPJ-CFNGYE-1-2023-2469
# 6   ocds-5wno2w-RE-APJ-EPA-002-2023-555086
# 7  ocds-5wno2w-RE-APJ-EPMMQ-01-2023-410205
# 8     ocds-5wno2w-RE-APJC-GADMA-01-23-2422
# 9       ocds-5wno2w-RE-CBVA-2023-001-84942
#
#                                           release_id
# 0  REAJ-CBBF-001-2023-166651-2023-08-22T19:29:19....  \
# 1  RE-APG-001-2023-2499-2023-08-22T19:27:03.571Z-...
# 2  REAJ-CBCB-001-2023-498171-2023-02-01T10:32:22....
# 3  RE-APJ-BCBG-04-2023-2528-2023-08-22T19:10:50.566Z
# 4  RE-APJ-EMOVEP-1-2023-315805-2023-08-22T19:28:3...
# 5  RREAPJ-CFNGYE-1-2023-2469-2023-08-22T19:45:25....
# 6  RE-APJ-EPA-002-2023-555086-2023-08-22T20:04:24...
# 7  RE-APJ-EPMMQ-01-2023-410205-2023-08-23T02:29:1...
# ...

# %%
#Columnas
contracts_2023_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ocid                           19 non-null     object
#  1   release_id                     19 non-null     object
#  2   id                             19 non-null     object
#  3   awardID                        19 non-null     object
#  4   title                          0 non-null      float64
#  5   description                    0 non-null      float64
#  6   status                         19 non-null     object
#  7   contractPeriod_startDate       19 non-null     object
#  8   contractPeriod_endDate         19 non-null     object
#  9   contractPeriod_maxExtentDate   0 non-null      float64
#  10  contractPeriod_durationInDays  19 non-null     int64
#  11  amount                         19 non-null     float64
# ...

# %% [markdown]
# ### extensions_2023_asesoria_y_patrocinio_juridico.csv

# %%
extensions_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[2]),sep=",")
extensions_2023_df.head(10)
# Out:
#                                            extension
# 0  https://raw.githubusercontent.com/open-contrac...
# 1  https://raw.githubusercontent.com/open-contrac...
# 2  https://raw.githubusercontent.com/open-contrac...
# 3  https://raw.githubusercontent.com/GobiernoFaci...
# 4  https://gitlab.com/dncp-opendata/ocds_auctions...
# 5  https://raw.githubusercontent.com/open-contrac...
# 6  https://raw.githubusercontent.com/open-contrac...

# %%
#Columnas
contracts_2023_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ocid                           19 non-null     object
#  1   release_id                     19 non-null     object
#  2   id                             19 non-null     object
#  3   awardID                        19 non-null     object
#  4   title                          0 non-null      float64
#  5   description                    0 non-null      float64
#  6   status                         19 non-null     object
#  7   contractPeriod_startDate       19 non-null     object
#  8   contractPeriod_endDate         19 non-null     object
#  9   contractPeriod_maxExtentDate   0 non-null      float64
#  10  contractPeriod_durationInDays  19 non-null     int64
#  11  amount                         19 non-null     float64
# ...

# %% [markdown]
# ### metadata_2023_asesoria_y_patrocinio_juridico.csv

# %%
metadata_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[3]),sep=",")
metadata_2023_df.head(10)
# Out:
#                                                  Uri  Version
# 0  https://portal.compraspublicas.gob.ec/sercop/d...      1.1  \
#
#                                        PublisherName PublisherScheme
# 0  Servicio Nacional de Contratación Pública (SER...            OCDS  \
#
#   PublisherUid                        PublisherUri
# 0  ocds-5wno2w  https://www.compraspublicas.gob.ec  \
#
#                                            License
# 0  https://creativecommons.org/licenses/by/3.0/ec/  \
#
#                                    PublicationPolicy             PublishedDate
# 0  https://datosabiertos.compraspublicas.gob.ec/P...  2023-09-01T21:15:38.820Z

# %%
#Columnas
metadata_2023_df.columns
# Out:
# Index(['Uri', 'Version', 'PublisherName', 'PublisherScheme', 'PublisherUid',
#        'PublisherUri', 'License', 'PublicationPolicy', 'PublishedDate'],
#       dtype='object')

# %% [markdown]
# ### planning_2023_asesoria_y_patrocinio_juridico.csv

# %%
planning_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[4]),sep=",")
planning_2023_df.head(10)
# Out:
#                                       ocid
# 0    ocds-5wno2w-REAJ-CBBF-001-2023-166651  \
# 1         ocds-5wno2w-RE-APG-001-2023-2499
# 2    ocds-5wno2w-REAJ-CBCB-001-2023-498171
# 3     ocds-5wno2w-RE-APJ-BCBG-04-2023-2528
# 4  ocds-5wno2w-RE-APJ-EMOVEP-1-2023-315805
# 5    ocds-5wno2w-RREAPJ-CFNGYE-1-2023-2469
# 6   ocds-5wno2w-RE-APJ-EPA-002-2023-555086
# 7  ocds-5wno2w-RE-APJ-EPMMQ-01-2023-410205
# 8     ocds-5wno2w-GADPRA-001-AJ-2023-94956
# 9     ocds-5wno2w-RE-APJC-GADMA-01-23-2422
#
#                                                   id
# 0  REAJ-CBBF-001-2023-166651-2023-08-22T19:29:19....  \
# 1  RE-APG-001-2023-2499-2023-08-22T19:27:03.571Z-...
# 2  REAJ-CBCB-001-2023-498171-2023-02-01T10:32:22....
# 3  RE-APJ-BCBG-04-2023-2528-2023-08-22T19:10:50.566Z
# 4  RE-APJ-EMOVEP-1-2023-315805-2023-08-22T19:28:3...
# 5  RREAPJ-CFNGYE-1-2023-2469-2023-08-22T19:45:25....
# 6  RE-APJ-EPA-002-2023-555086-2023-08-22T20:04:24...
# 7  RE-APJ-EPMMQ-01-2023-410205-2023-08-23T02:29:1...
# ...

# %%
#Columnas
planning_2023_df.columns
# Out:
# Index(['ocid', 'id', 'rationale', 'budget_id', 'budget_description',
#        'budget_amount', 'budget_currency'],
#       dtype='object')

# %%
planning_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ocid                30 non-null     object
#  1   id                  30 non-null     object
#  2   rationale           30 non-null     object
#  3   budget_id           30 non-null     object
#  4   budget_description  0 non-null      float64
#  5   budget_amount       30 non-null     float64
#  6   budget_currency     30 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 1.8+ KB

# %% [markdown]
# ### releases_2023_asesoria_y_patrocinio_juridico.csv

# %%
releases_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[5]),sep=",")
releases_2023_df.head(10)
# Out:
#                                       ocid
# 0    ocds-5wno2w-REAJ-CBBF-001-2023-166651  \
# 1         ocds-5wno2w-RE-APG-001-2023-2499
# 2    ocds-5wno2w-REAJ-CBCB-001-2023-498171
# 3     ocds-5wno2w-RE-APJ-BCBG-04-2023-2528
# 4  ocds-5wno2w-RE-APJ-EMOVEP-1-2023-315805
# 5    ocds-5wno2w-RREAPJ-CFNGYE-1-2023-2469
# 6   ocds-5wno2w-RE-APJ-EPA-002-2023-555086
# 7  ocds-5wno2w-RE-APJ-EPMMQ-01-2023-410205
# 8     ocds-5wno2w-GADPRA-001-AJ-2023-94956
# 9     ocds-5wno2w-RE-APJC-GADMA-01-23-2422
#
#                                                   id initiationType
# 0  REAJ-CBBF-001-2023-166651-2023-08-22T19:29:19....         tender  \
# 1  RE-APG-001-2023-2499-2023-08-22T19:27:03.571Z-...         tender
# 2  REAJ-CBCB-001-2023-498171-2023-02-01T10:32:22....         tender
# 3  RE-APJ-BCBG-04-2023-2528-2023-08-22T19:10:50.566Z         tender
# 4  RE-APJ-EMOVEP-1-2023-315805-2023-08-22T19:28:3...         tender
# 5  RREAPJ-CFNGYE-1-2023-2469-2023-08-22T19:45:25....         tender
# ...

# %%
#Columnas
releases_2023_df.columns
# Out:
# Index(['ocid', 'id', 'initiationType', 'buyer_id', 'buyer_name', 'language',
#        'date', 'tag'],
#       dtype='object')

# %%
releases_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ocid            30 non-null     object
#  1   id              30 non-null     object
#  2   initiationType  30 non-null     object
#  3   buyer_id        30 non-null     object
#  4   buyer_name      30 non-null     object
#  5   language        30 non-null     object
#  6   date            30 non-null     object
#  7   tag             30 non-null     object
# dtypes: object(8)
# memory usage: 2.0+ KB

# %% [markdown]
# ### suppliers_2023_asesoria_y_patrocinio_juridico.csv

# %%
suppliers_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[6]),sep=",")
suppliers_2023_df.head(10)
# Out:
#                                       ocid
# 0    ocds-5wno2w-REAJ-CBBF-001-2023-166651  \
# 1         ocds-5wno2w-RE-APG-001-2023-2499
# 2    ocds-5wno2w-REAJ-CBCB-001-2023-498171
# 3     ocds-5wno2w-RE-APJ-BCBG-04-2023-2528
# 4  ocds-5wno2w-RE-APJ-EMOVEP-1-2023-315805
# 5    ocds-5wno2w-RREAPJ-CFNGYE-1-2023-2469
# 6   ocds-5wno2w-RE-APJ-EPA-002-2023-555086
# 7  ocds-5wno2w-RE-APJ-EPMMQ-01-2023-410205
# 8     ocds-5wno2w-GADPRA-001-AJ-2023-94956
# 9     ocds-5wno2w-RE-APJC-GADMA-01-23-2422
#
#                                           release_id
# 0  REAJ-CBBF-001-2023-166651-2023-08-22T19:29:19....  \
# 1  RE-APG-001-2023-2499-2023-08-22T19:27:03.571Z-...
# 2  REAJ-CBCB-001-2023-498171-2023-02-01T10:32:22....
# 3  RE-APJ-BCBG-04-2023-2528-2023-08-22T19:10:50.566Z
# 4  RE-APJ-EMOVEP-1-2023-315805-2023-08-22T19:28:3...
# 5  RREAPJ-CFNGYE-1-2023-2469-2023-08-22T19:45:25....
# 6  RE-APJ-EPA-002-2023-555086-2023-08-22T20:04:24...
# 7  RE-APJ-EPMMQ-01-2023-410205-2023-08-23T02:29:1...
# ...

# %%
#Columnas
suppliers_2023_df.columns
# Out:
# Index(['ocid', 'release_id', 'award_id', 'id', 'name'], dtype='object')

# %%
suppliers_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ocid        29 non-null     object
#  1   release_id  29 non-null     object
#  2   award_id    29 non-null     object
#  3   id          29 non-null     object
#  4   name        29 non-null     object
# dtypes: object(5)
# memory usage: 1.3+ KB

# %% [markdown]
# ### tender_2023_asesoria_y_patrocinio_juridico.csv

# %%
tender_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[7]),sep=",")
tender_2023_df.head(10)
# Out:
#                                       ocid
# 0    ocds-5wno2w-REAJ-CBBF-001-2023-166651  \
# 1         ocds-5wno2w-RE-APG-001-2023-2499
# 2    ocds-5wno2w-REAJ-CBCB-001-2023-498171
# 3     ocds-5wno2w-RE-APJ-BCBG-04-2023-2528
# 4  ocds-5wno2w-RE-APJ-EMOVEP-1-2023-315805
# 5    ocds-5wno2w-RREAPJ-CFNGYE-1-2023-2469
# 6   ocds-5wno2w-RE-APJ-EPA-002-2023-555086
# 7  ocds-5wno2w-RE-APJ-EPMMQ-01-2023-410205
# 8     ocds-5wno2w-GADPRA-001-AJ-2023-94956
# 9     ocds-5wno2w-RE-APJC-GADMA-01-23-2422
#
#                                           release_id
# 0  REAJ-CBBF-001-2023-166651-2023-08-22T19:29:19....  \
# 1  RE-APG-001-2023-2499-2023-08-22T19:27:03.571Z-...
# 2  REAJ-CBCB-001-2023-498171-2023-02-01T10:32:22....
# 3  RE-APJ-BCBG-04-2023-2528-2023-08-22T19:10:50.566Z
# 4  RE-APJ-EMOVEP-1-2023-315805-2023-08-22T19:28:3...
# 5  RREAPJ-CFNGYE-1-2023-2469-2023-08-22T19:45:25....
# 6  RE-APJ-EPA-002-2023-555086-2023-08-22T20:04:24...
# 7  RE-APJ-EPMMQ-01-2023-410205-2023-08-23T02:29:1...
# ...

# %%
#Columnas
tender_2023_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status',
#        'procuringEntity_id', 'procuringEntity_name', 'value_amount',
#        'value_currency', 'procurementMethod', 'procurementMethodDetails',
#        'mainProcurementCategory', 'awardCriteria', 'tenderPeriod_startDate',
#        'tenderPeriod_endDate', 'tenderPeriod_maxExtentDate',
#        'tenderPeriod_durationInDays', 'enquiryPeriod_startDate',
#        'enquiryPeriod_endDate', 'enquiryPeriod_maxExtentDate',
#        'enquiryPeriod_durationInDays', 'hasEnquiries', 'eligibilityCriteria',
#        'awardPeriod_startDate', 'awardPeriod_endDate',
#        'awardPeriod_maxExtentDate', 'awardPeriod_durationInDays',
#        'numberOfTenderers'],
#       dtype='object')

# %%
tender_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ocid                          30 non-null     object
#  1   release_id                    30 non-null     object
#  2   id                            30 non-null     object
#  3   title                         30 non-null     object
#  4   description                   30 non-null     object
#  5   status                        30 non-null     object
#  6   procuringEntity_id            30 non-null     object
#  7   procuringEntity_name          30 non-null     object
#  8   value_amount                  30 non-null     float64
#  9   value_currency                30 non-null     object
#  10  procurementMethod             30 non-null     object
#  11  procurementMethodDetails      30 non-null     object
# ...
